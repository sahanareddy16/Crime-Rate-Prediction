# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath=(r"C:\Users\sahan\OneDrive\Documents\01_District_wise_crimes_committed_IPC_2001_2012.csv")
crimes=pd.read_csv(filepath)
crimes
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
crimes.head() # prints top 5 rows
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
crimes.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df=crimes.drop(['ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER','CUSTODIAL RAPE',
       'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
       'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
       'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
       'PREPARATION AND ASSEMBLY FOR DACOITY', 'BURGLARY',
       'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
       'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
       'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
       'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES'],axis=1)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'RAPE', 'ROBBERY', 'THEFT',
#        'DOWRY DEATHS', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# STATE/UT            0
# DISTRICT            0
# YEAR                0
# MURDER              0
# RAPE                0
# ROBBERY             0
# THEFT               0
# DOWRY DEATHS        0
# TOTAL IPC CRIMES    0
# dtype: int64

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  RAPE  ROBBERY  THEFT  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101    50       41    199
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151    23       16    366
# 2  ANDHRA PRADESH       CHITTOOR  2001     101    27       14    723
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80    20        4    173
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82    23       25   1021
#
#    DOWRY DEATHS  TOTAL IPC CRIMES
# 0            16              4154
# 1             7              4125
# 2            14              5818
# 3            17              3140
# 4            12              6507

# %%
df.tail()
# Out:
#          STATE/UT     DISTRICT  YEAR  MURDER  RAPE  ROBBERY  THEFT  \
# 9012  LAKSHADWEEP  LAKSHADWEEP  2012       0     0        0      7
# 9013  LAKSHADWEEP        TOTAL  2012       0     0        0      7
# 9014   PUDUCHERRY     KARAIKAL  2012       5     6        3     81
# 9015   PUDUCHERRY   PUDUCHERRY  2012      24     7       13    577
# 9016   PUDUCHERRY        TOTAL  2012      29    13       16    658
#
#       DOWRY DEATHS  TOTAL IPC CRIMES
# 9012             0                60
# 9013             0                60
# 9014             0               787
# 9015             0              3494
# 9016             0              4281

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   STATE/UT          9017 non-null   object
#  1   DISTRICT          9017 non-null   object
#  2   YEAR              9017 non-null   int64
#  3   MURDER            9017 non-null   int64
#  4   RAPE              9017 non-null   int64
#  5   ROBBERY           9017 non-null   int64
#  6   THEFT             9017 non-null   int64
#  7   DOWRY DEATHS      9017 non-null   int64
#  8   TOTAL IPC CRIMES  9017 non-null   int64
# dtypes: int64(7), object(2)
# memory usage: 634.1+ KB

# %%
df.describe()
# Out:
#               YEAR      MURDER         RAPE      ROBBERY         THEFT  \
# count  9017.000000  9017.00000  9017.000000  9017.000000   9017.000000
# mean   2006.629034    89.28535    53.041366    55.066430    776.428968
# std       3.463623   327.27503   190.741450   220.576876   2935.008640
# min    2001.000000     0.00000     0.000000     0.000000      0.000000
# 25%    2004.000000    18.00000     8.000000     6.000000     88.000000
# 50%    2007.000000    38.00000    20.000000    17.000000    217.000000
# 75%    2010.000000    66.00000    41.000000    37.000000    466.000000
# max    2012.000000  7601.00000  3425.000000  6949.000000  53449.000000
#
#        DOWRY DEATHS  TOTAL IPC CRIMES
# count   9017.000000       9017.000000
# mean      20.228901       5310.115116
# std       96.970466      18524.381119
# min        0.000000          0.000000
# 25%        1.000000        853.000000
# 50%        5.000000       2096.000000
# 75%       16.000000       3972.000000
# ...

# %%
# SCatter plot
plt.scatter(df.ST,df.MURDER)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12068\2867270704.py in <module>
#       1 # SCatter plot
# ----> 2 plt.scatter(df.STATE,df.MURDER)
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'STATE'

# %%
plt.scatter(df.YEAR,df.MURDER)
plt.title("Distribution of datapoints")
sns.set()
plt.show()

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  RAPE  ROBBERY  THEFT  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101    50       41    199
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151    23       16    366
# 2  ANDHRA PRADESH       CHITTOOR  2001     101    27       14    723
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80    20        4    173
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82    23       25   1021
#
#    DOWRY DEATHS  TOTAL IPC CRIMES
# 0            16              4154
# 1             7              4125
# 2            14              5818
# 3            17              3140
# 4            12              6507

# %%
# Extra visualization
# relplot show the relationship between two variables with semantic mappings of subsets
# by default relplot type is scatter we can change to line ------- kind=line)
sns.relplot(data=crimes, x="YEAR", y="MURDER")

# %%
extraval = df
extraval.head()
sns.relplot(data=extraval, x="THEFT", y="MURDER", hue="YEAR")

# %%
sns.set_context("poster") # increases plot size
sns.relplot(data=extraval, x="MURDER", y="RAPE", hue="YEAR",col="YEAR",col_wrap=3)

# %%
sns.set_context("poster") # increases plot size
sns.relplot(data=extraval, x="YEAR", y="MURDER", kind="line",ci=None)

# %%
'''
Pair plot creates a grid of Axes such that each numeric variable in data will be shared acr
single row and the x-axes across a single column. The diagonal plots are treated
differently: a univariate distribution plot is drawn to show the marginal distribution of t
'''
import seaborn as sns
from matplotlib import pyplot as plt
df=df
sns.set_style("ticks")
sns.pairplot(df,hue = 'YEAR',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %%
sns.pointplot( x="YEAR", y="MURDER", data=extraval)
plt.show()

# %%
SA=df
SA.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  RAPE  ROBBERY  THEFT  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101    50       41    199
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151    23       16    366
# 2  ANDHRA PRADESH       CHITTOOR  2001     101    27       14    723
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80    20        4    173
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82    23       25   1021
#
#    DOWRY DEATHS  TOTAL IPC CRIMES
# 0            16              4154
# 1             7              4125
# 2            14              5818
# 3            17              3140
# 4            12              6507

# %%
'''
Joint Plot draws a plot of two variables with bivariate and univariate graphs.
It uses the Scatter Plot and Histogram.
Joint Plot can also display data using Kernel Density Estimate (KDE) and Hexagons
'''
# Add regression line to scatter plot and kernel density estimate to histogram
sns.jointplot(x='YEAR', y='MURDER', data=SA, kind='reg')

# %%
# Display kernel density estimate instead of scatter plot and histogram
sns.jointplot(x='YEAR', y='MURDER', data=SA, kind='kde')

# %%
# Display hexagons instead of points in scatter plot
sns.jointplot(x='YEAR', y='MURDER', data=SA, kind='hex')

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
ax = sns.violinplot(x=SA['YEAR'])

# %%
ax = sns.regplot(x='YEAR', y='THEFT', data=SA,ci=None)

# %%
y = df['YEAR'] # dependent variable
X = df[['MURDER']] # independent variable

# %%
X
# Out:
#       MURDER
# 0        101
# 1        151
# 2        101
# 3         80
# 4         82
# ...      ...
# 9012       0
# 9013       0
# 9014       5
# 9015      24
# 9016      29
#
# [9017 rows x 1 columns]

# %%
# Step 3 : CREATE TRAINING AND TESTING DATASET
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
#TRAIN THE MODEL
X_train.shape # size of training dataset
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient (m): ', regressor.coef_)
print('Linear Model Coefficient (b): ', regressor.intercept_)
# Out:
# Linear Model Coefficient (m):  [-0.00012749]
# Linear Model Coefficient (b):  2006.6368077050008

# %%
# TEST THE MODEL
y_predict = regressor.predict( X_test)
y_predict
# Out:
# array([2006.63005069, 2006.63311047, 2006.50510968, ..., 2006.632728  ,
#        2006.62597098, 2006.62737338])

# %%
y_test
# Out:
# 6484    2009
# 6974    2010
# 3069    2005
# 8036    2011
# 5152    2008
#         ...
# 3929    2006
# 968     2002
# 2431    2004
# 7685    2011
# 4690    2007
# Name: YEAR, Length: 2255, dtype: int64

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, regressor.predict(X_train), color = 'red')
plt.ylabel('MURDERS')
plt.xlabel('YEAR')
plt.title('MURDERS OCCURED IN PAST YEARS')
# Out:
# Text(0.5, 1.0, 'MURDERS OCCURED IN PAST YEARS')

# %%
# VISUALIZE TEST SET RESULTS
plt.scatter(X_test, y_test, color = 'gray')
plt.plot(X_test, regressor.predict(X_test), color = 'red')
plt.ylabel('MURDERS')
plt.xlabel('YEAR')
plt.title('MURDERS OCCURRED IN PAST YEARS')
# Out:
# Text(0.5, 1.0, 'MURDERS OCCURRED IN PAST YEARS')

# %%
# Display Mean Square Error , SLope and Intercept
from sklearn.metrics import mean_squared_error
acc = mean_squared_error(y_test,y_predict)
print("Mean Square Error : ",acc)
wts = regressor.coef_
incpt = regressor.intercept_
print("Slope :",wts,"\nIntercept ",incpt)
# Out:
# Mean Square Error :  12.069770994366495
# Slope : [-0.00012749]
# Intercept  2006.6368077050008

# %%
import sklearn.metrics as sm
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, y_predict),2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_predict),2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_predict),2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_predict),2)) 
print("R2 score =", round(sm.r2_score(y_test, y_predict),2))
# Out:
# Mean absolute error = 3.03
# Mean squared error = 12.07
# Median absolute error = 3.36
# Explain variance score = 0.0
# R2 score = 0.0
